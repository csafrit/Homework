# %%
#import modules
import pandas as pd
import numpy as np
import json
import os
import sys
import csv

# %%
#upload data.parse data.
data=json.load(open("../Weel-04-Pandas/Instructions/HeroesOfPymoli/purchase_data.json"))
dataframe=pd.DataFrame(data)
dataframe.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
#This is a round-about way of uploading the data I used to start.
with open("../Weel-04-Pandas/Instructions/HeroesOfPymoli/purchase_data.json") as json_data:
    fantasy_data = json.load(json_data)
    print(fantasy_data)
# Out:
# [{'SN': 'Aelalis34', 'Age': 38, 'Gender': 'Male', 'Item ID': 165, 'Item Name': 'Bone Crushing Silver Skewer', 'Price': 3.37}, {'SN': 'Eolo46', 'Age': 21, 'Gender': 'Male', 'Item ID': 119, 'Item Name': 'Stormbringer, Dark Blade of Ending Misery', 'Price': 2.32}, {'SN': 'Assastnya25', 'Age': 34, 'Gender': 'Male', 'Item ID': 174, 'Item Name': 'Primitive Blade', 'Price': 2.46}, {'SN': 'Pheusrical25', 'Age': 21, 'Gender': 'Male', 'Item ID': 92, 'Item Name': 'Final Critic', 'Price': 1.36}, {'SN': 'Aela59', 'Age': 23, 'Gender': 'Male', 'Item ID': 63, 'Item Name': 'Stormfury Mace', 'Price': 1.27}, {'SN': 'Tanimnya91', 'Age': 20, 'Gender': 'Male', 'Item ID': 10, 'Item Name': 'Sleepwalker', 'Price': 1.73}, {'SN': 'Undjaskla97', 'Age': 20, 'Gender': 'Male', 'Item ID': 153, 'Item Name': 'Mercenary Sabre', 'Price': 4.57}, {'SN': 'Iathenudil29', 'Age': 29, 'Gender': 'Female', 'Item ID': 169, 'Item Name': 'Interrogator, Blood Blade of the Queen', 'Price': 3.32}, {'SN': 'Sondenasta63', 'Age': 25, 'Gender': 'Male', 'Item ID': 118, 'Item Name': 'Ghost Reaver, Longsword of Magic', 'Price': 2.77}, {'SN': 'Hilaerin92', 'Age': 31, 'Gender': 'Male', 'Item ID': 99, 'Item Name': 'Expiration, Warscythe Of Lost Worlds', 'Price': 4.53}, {'SN': 'Chamosia29', 'Age': 24, 'Gender': 'Male', 'Item ID': 57, 'Item Name': 'Despair, Favor of Due Diligence', 'Price': 3.81}, {'SN': 'Sally64', 'Age': 20, 'Gender': 'Male', 'Item ID': 47, 'Item Name': 'Alpha, Reach of Ending Hope', 'Price': 1.55}, {'SN': 'Iskossa88', 'Age': 30, 'Gender': 'Male', 'Item ID': 81, 'Item Name': 'Dreamkiss', 'Price': 4.06}, {'SN': 'Seorithstilis90', 'Age': 23, 'Gender': 'Male', 'Item ID': 77, 'Item Name': 'Piety, Guardian of Riddles', 'Price': 3.68}, {'SN': 'Sundast29', 'Age': 40, 'Gender': 'Male', 'Item ID': 44, 'Item Name': 'Bonecarvin Battle Axe', 'Price': 2.46}, {'SN': 'Haellysu29', 'Age': 21, 'Gender': 'Male', 'Item ID': 96, 'Item Name': 'Blood-Forged Skeletal Spine', 'Price': 4.77}, {'SN': 'Sundista85', 'Age': 22, 'Gender': 'Female', 'Item ID': 123, 'Item Name': "Twilight's Carver", 'Price': 1.14}, {'SN': 'Aenarap34', 'Age': 22, 'Gender': 'Female', 'Item ID': 59, 'Item Name': 'Lightning, Etcher of the King', 'Price': 1.65}, {'SN': 'Iskista88', 'Age': 28, 'Gender': 'Male', 'Item ID': 91, 'Item Name': 'Celeste', 'Price': 3.71}, {'SN': 'Assossa43', 'Age': 31, 'Gender': 'Male', 'Item ID': 177, 'Item Name': 'Winterthorn, Defender of Shifting Worlds', 'Price': 4.89}, {'SN': 'Irith83', 'Age': 24, 'Gender': 'Male', 'Item ID': 78, 'Item Name': 'Glimmer, Ender of the Moon', 'Price': 2.33}, {'SN': 'Iaralrgue74', 'Age': 15, 'Gender': 'Male', 'Item ID': 3, 'Item Name': 'Phantomlight', 'Price': 1.79}, {'SN': 'Deural48', 'Age': 11, 'Gender': 'Female', 'Item ID': 11, 'Item Name': 'Brimstone', 'Price': 2.52}, {'SN': 'Chanosia65', 'Age': 19, 'Gender': 'Male', 'Item ID': 183, 'Item Name': "Dragon's Greatsword", 'Price': 2.36}, {'SN': 'Qarwen67', 'Age': 11, 'Gender': 'Male', 'Item ID': 65, 'Item Name': 'Conqueror Adamantite Mace', 'Price': 1.96}, {'SN': 'Idai61', 'Age': 21, 'Gender': 'Male', 'Item ID': 63, 'Item Name': 'Stormfury Mace', 'Price': 1.27}, {'SN': 'Aerithllora36', 'Age': 29, 'Gender': 'Male', 'Item ID': 132, 'Item Name': 'Persuasion', 'Price': 3.9}, {'SN': 'Assastnya25', 'Age': 34, 'Gender': 'Male', 'Item ID': 106, 'Item Name': 'Crying Steel Sickle', 'Price': 2.29}, {'SN': 'Ilariarin45', 'Age': 15, 'Gender': 'Male', 'Item ID': 49, 'Item Name': 'The Oculus, Token of Lost Worlds', 'Price': 4.23}, {'SN': 'Phaedai25', 'Age': 16, 'Gender': 'Female', 'Item ID': 45, 'Item Name': 'Glinting Glass Edge', 'Price': 2.46}, {'SN': 'Eulaeria40', 'Age': 21, 'Gender': 'Female', 'Item ID': 155, 'Item Name': 'War-Forged Gold Deflector', 'Price': 3.73}, {'SN': 'Iarilis73', 'Age': 18, 'Gender': 'Male', 'Item ID': 37, 'Item Name': 'Shadow Strike, Glory of Ending Hope', 'Price': 1.93}, {'SN': 'Malunil62', 'Age': 19, 'Gender': 'Male', 'Item ID': 48, 'Item Name': 'Rage, Legacy of the Lone Victor', 'Price': 4.32}, {'SN ...

# %%
print(type(fantasy_data))

#This is a list. It would be better to work with a dictionary or dataframe instead of an array.
# Out:
# <class 'list'>

# %%
#Tried to convert json to csv file for easier manipulation. Probably a weak attempt. 
fantasy_data2 = csv.writer(open("..//Weel-04-Pandas//Instructions//HeroesOfPymoli//purchase_data.json", "wb+", "r", "w", encoding = "utf-8"))

#This wasn't working so I explored the vast internet horizon and discovered a json to csv converter.
#Creating a json to csv converter could be a future mini-project
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-6fe03058bf9f> in <module>()
#       1 #Tried to convert json to csv file for easier manipulation. Probably a weak attempt.
# ----> 2 fantasy_data2 = csv.writer(open("..//Weel-04-Pandas//Instructions//HeroesOfPymoli//purchase_data.json", "wb+", "r", "w", encoding = "utf-8"))
#       3
#       4 #This wasn't working so I explored the vast internet horizon and discovered a json to csv converter.
#       5 #Creating a json to csv converter could be a future mini-project
#
# TypeError: an integer is required (got type str)

# %%
#upload csv data
csv_data = "../Weel-04-Pandas/codebeautify.csv"
fantasy_data = pd.read_csv(csv_data)
fantasy_data.head()
# Out:
#              SN  Age Gender  Item ID  \
# 0     Aelalis34   38   Male      165
# 1        Eolo46   21   Male      119
# 2   Assastnya25   34   Male      174
# 3  Pheusrical25   21   Male       92
# 4        Aela59   23   Male       63
#
#                                    Item Name  Price
# 0                Bone Crushing Silver Skewer   3.37
# 1  Stormbringer, Dark Blade of Ending Misery   2.32
# 2                            Primitive Blade   2.46
# 3                               Final Critic   1.36
# 4                             Stormfury Mace   1.27

# %%
#Total number of players
total_players = len(fantasy_data["SN"].unique())
print(total_players)
# Out:
# 573

# %%
#Number of Unique Items
unique_items_group = fantasy_data.groupby(["Item ID"])
total_items = len(unique_items_group)
print(total_items)
# Out:
# 183

# %%
#Average Purchase Price
average_Price = fantasy_data["Price"].mean()
print(average_Price)
# Out:
# 2.931192307692303

# %%
 #Total Number of Purchases
total_Purchases = fantasy_data["Price"].count()
print(total_Purchases)
# Out:
# 780

# %%
#Total Revenue
total_Revenue = fantasy_data["Price"].sum()
print(total_Revenue)
# Out:
# 2286.3299999999963

# %%
#Create df with unique SN to work with to remove duplicate players.
#sys.setrecursionlimit(10000) <--- this...crashed the program
fantasy_data1 = fantasy_data.drop_duplicates(["SN"])
fantasy_data1.head()
# Out:
#              SN  Age Gender  Item ID  \
# 0     Aelalis34   38   Male      165
# 1        Eolo46   21   Male      119
# 2   Assastnya25   34   Male      174
# 3  Pheusrical25   21   Male       92
# 4        Aela59   23   Male       63
#
#                                    Item Name  Price
# 0                Bone Crushing Silver Skewer   3.37
# 1  Stormbringer, Dark Blade of Ending Misery   2.32
# 2                            Primitive Blade   2.46
# 3                               Final Critic   1.36
# 4                             Stormfury Mace   1.27

# %%
#Gender
total_gender = fantasy_data1["Gender"].count()

# %%
#Percentage and Count of Male Players
male = fantasy_data1["Gender"].value_counts()['Male']
male_percent = (male/total_gender) * 100
print(f"Male: {male}\n% Male: {male_percent}")
# Out:
# Male: 465
# % Male: 81.15183246073299

# %%
#Percentage and Count of Female Players
female = fantasy_data1["Gender"].value_counts()['Female']
female_percent = (female/total_gender) * 100
print(f"Female: {female}\n % Female: {female_percent}")
# Out:
# Female: 100
#  % Female: 17.452006980802793

# %%
#Percentage and Count of Other / Non-Disclosed
non_gender_specific = total_gender - male - female
non_gender_specific_percent = (non_gender_specific/total_gender) * 100
print(f" non_specfic: {non_gender_specific} \n % non_specifc: {non_gender_specific}")
# Out:
#  non_specfic: 8
#  % non_specifc: 8

# %%
#By Gender
gender_group = fantasy_data1.groupby(["Gender"])
gender_group.all()
# Out:
#                         Age  Item ID  Item Name  Price    SN
# Gender
# Female                 True     True       True   True  True
# Male                   True    False       True   True  True
# Other / Non-Disclosed  True     True       True   True  True

# %%
#Gender Purchase Count
gender_group["Item ID"].count()
# Out:
# Gender
# Female                   100
# Male                     465
# Other / Non-Disclosed      8
# Name: Item ID, dtype: int64

# %%
#Gender Average Purchase Price
gender_group["Price"].mean()
# Out:
# Gender
# Female                   2.887900
# Male                     2.988645
# Other / Non-Disclosed    3.447500
# Name: Price, dtype: float64

# %%
#Total Purchase Value
gender_group["Price"].sum()
# Out:
# Gender
# Female                    288.79
# Male                     1389.72
# Other / Non-Disclosed      27.58
# Name: Price, dtype: float64

# %%
#Normalized Totals
#df_norm = (df - df.mean()) / (df.max() - df.min())

#df_norm

# %%
#Again by bins of 4 years
#Identify range
age_low = fantasy_data["Age"].min()
age_high = fantasy_data["Age"].max()
print(age_low, age_high)
# Out:
# 7 45

# %%
#create bins

age_bins = [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48]
age_ranges = ["4-8", "8-12", "12-16", "16-20", "20-24", "24-28", "28-32", "32-36", "36-40", "40-44", "44-48"]

# %%
#place ages from fantasy data into bins

fantasy_data["Age Range"] = pd.cut(fantasy_data["Age"], age_bins, labels=age_ranges)
fantasy_data.head()
# Out:
#              SN  Age Gender  Item ID  \
# 0     Aelalis34   38   Male      165
# 1        Eolo46   21   Male      119
# 2   Assastnya25   34   Male      174
# 3  Pheusrical25   21   Male       92
# 4        Aela59   23   Male       63
#
#                                    Item Name  Price Age Range
# 0                Bone Crushing Silver Skewer   3.37     36-40
# 1  Stormbringer, Dark Blade of Ending Misery   2.32     20-24
# 2                            Primitive Blade   2.46     32-36
# 3                               Final Critic   1.36     20-24
# 4                             Stormfury Mace   1.27     20-24

# %%
#Group by Age Range, (optional) find oldest in each age group
age_groups = fantasy_data.groupby("Age Range")
age_groups.mean()
# Out:
#                  Age     Item ID     Price  SN_count  \
# Age Range
# 4-8         7.136364   85.909091  2.788182  1.909091
# 8-12       10.541667   87.125000  3.385417  1.750000
# 12-16      14.942529   92.816092  2.745862  1.597701
# 16-20      19.248447   84.248447  2.907019  1.596273
# 20-24      22.647059   89.605042  2.924748  1.487395
# 24-28      25.634615   93.855769  2.974712  1.711538
# 28-32      30.257576   91.166667  3.061970  2.030303
# 32-36      34.394737  105.631579  2.981053  1.578947
# 36-40      38.648649  112.972973  2.901351  2.135135
# 40-44      42.500000   83.500000  2.960000  1.000000
# 44-48      45.000000  124.000000  2.720000  1.000000
#
#            User_total_purchase_value
# Age Range
# 4-8                         2.788182
# 8-12                        3.385417
# 12-16                       2.745862
# 16-20                       2.907019
# 20-24                       2.924748
# 24-28                       2.974712
# 28-32                       3.061970
# 32-36                       2.981053
# 36-40                       2.901351
# 40-44                       2.960000
# 44-48                       2.720000

# %%
#Age Purchase Count
age_groups["Item ID"].count()
# Out:
# Age Range
# 4-8       22
# 8-12      24
# 12-16     87
# 16-20    161
# 20-24    238
# 24-28    104
# 28-32     66
# 32-36     38
# 36-40     37
# 40-44      2
# 44-48      1
# Name: Item ID, dtype: int64

# %%
#Age Average Purchase Price
age_groups["Price"].mean()
# Out:
# Age Range
# 4-8      2.788182
# 8-12     3.385417
# 12-16    2.745862
# 16-20    2.907019
# 20-24    2.924748
# 24-28    2.974712
# 28-32    3.061970
# 32-36    2.981053
# 36-40    2.901351
# 40-44    2.960000
# 44-48    2.720000
# Name: Price, dtype: float64

# %%
#Age Total Purchase Value
age_groups["Price"].sum()
# Out:
# Age Range
# 4-8       61.34
# 8-12      81.25
# 12-16    238.89
# 16-20    468.03
# 20-24    696.09
# 24-28    309.37
# 28-32    202.09
# 32-36    113.28
# 36-40    107.35
# 40-44      5.92
# 44-48      2.72
# Name: Price, dtype: float64

# %%
#Age Normalized totals

# %%
#Adds column of how many times a SN appears to fantasy_data
fantasy_data["SN_count"] = fantasy_data.groupby(['SN'])['SN'].transform('count')

# %%
fantasy_data["SN_identifier"] = pd.Categorical(fantasy_data.stack()).codes.reshape(fantasy_data.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SN_identifier'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in set(self, item, value, check)
#    3714         try:
# -> 3715             loc = self.items.get_loc(item)
#    3716         except KeyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SN_identifier'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-f7a629b55bf0> in <module>()
# ----> 1 fantasy_data["SN_identifier"] = pd.Categorical(fantasy_data.stack()).codes.reshape(fantasy_data.shape)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2396         self._ensure_valid_index(value)
#    2397         value = self._sanitize_column(key, value)
# -> 2398         NDFrame._set_item(self, key, value)
#    2399
#    2400         # check if we are modifying a copy
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    1757
#    1758     def _set_item(self, key, value):
# -> 1759         self._data.set(key, value)
#    1760         self._clear_item_cache()
#    1761
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in set(self, item, value, check)
#    3716         except KeyError:
#    3717             # This item wasn't present, just insert at end
# -> 3718             self.insert(len(self.items), item, value)
#    3719             return
#    3720
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    3817
#    3818         block = make_block(values=value, ndim=self.ndim,
# -> 3819                            placement=slice(loc, loc + 1))
#    3820
#    3821         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2717                      placement=placement, dtype=dtype)
#    2718
# -> 2719     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2720
#    2721 # TODO: flexible with index=None and/or items=None
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim, fastpath)
#     113             raise ValueError('Wrong number of items passed %d, placement '
#     114                              'implies %d' % (len(self.values),
# --> 115                                              len(self.mgr_locs)))
#     116
#     117     @property
#
# ValueError: Wrong number of items passed 9, placement implies 1

# %%
##Total purchase value = total of how much they have spent
#User_total_purchase_value = average of price and SN_count

#fantasy_data["User_total_purchase_value"] = (fantasy_data['SN_count'] * fantasy_data['Price'] / fantasy_data["SN_count"]

# %%
#Identify the the top 5 spenders in the game
#Most common SNs. These people purchase most often. Doesn't necessarily mean they spend the most. 
#Need to combine this with price data

#fantasy_data["SN_unique"] = fantasy_data["SN"].value_counts().index.drop=True
#print(SN_unique)
fantasy_data.head()
# Out:
#              SN  Age Gender  Item ID  \
# 0     Aelalis34   38   Male      165
# 1        Eolo46   21   Male      119
# 2   Assastnya25   34   Male      174
# 3  Pheusrical25   21   Male       92
# 4        Aela59   23   Male       63
#
#                                    Item Name  Price Age Range  SN_count  \
# 0                Bone Crushing Silver Skewer   3.37     36-40         2
# 1  Stormbringer, Dark Blade of Ending Misery   2.32     20-24         1
# 2                            Primitive Blade   2.46     32-36         2
# 3                               Final Critic   1.36     20-24         1
# 4                             Stormfury Mace   1.27     20-24         1
#
#    User_total_purchase_value
# 0                       3.37
# 1                       2.32
# 2                       2.46
# 3                       1.36
# 4                       1.27

# %%
user_purchase_value_sorted = fantasy_data.sort_values(["User_total_purchase_value"], ascending=False)
user_purchase_value_sorted.head()
# Out:
#                 SN  Age  Gender  Item ID Item Name  Price Age Range  SN_count  \
# 83   Frichaststa61   25  Female       32   Orenmir   4.95     24-28         1
# 50    Saistyphos30   32  Female       32   Orenmir   4.95     28-32         2
# 657     Tyarithn67   28    Male       32   Orenmir   4.95     24-28         1
# 388    Palurrian69   15    Male       32   Orenmir   4.95     12-16         1
# 227      Qiluard68   20    Male       32   Orenmir   4.95     16-20         1
#
#      User_total_purchase_value
# 83                        4.95
# 50                        4.95
# 657                       4.95
# 388                       4.95
# 227                       4.95

# %%
#Total purchase value = total of how much they have spent
#Per unique SN, the sum of all the price values

#.value_counts() indicates frequency, Price is listed. 
#total_user_purchase_value = [fantasy_data["SN_unique"] * fantasy_data["Price"]]
#print(total_user_purchase_value)

# %%
price_sorted = fantasy_data.sort_values(["Price"], ascending=False)
price_sorted.head()
#most expensive item is 4.95.
# Out:
#                 SN  Age  Gender  Item ID Item Name  Price Age Range  SN_count
# 83   Frichaststa61   25  Female       32   Orenmir   4.95     24-28       1.0
# 50    Saistyphos30   32  Female       32   Orenmir   4.95     28-32       2.0
# 657     Tyarithn67   28    Male       32   Orenmir   4.95     24-28       1.0
# 388    Palurrian69   15    Male       32   Orenmir   4.95     12-16       1.0
# 227      Qiluard68   20    Male       32   Orenmir   4.95     16-20       1.0

# %%
print(4.95 * 3)
#If someone purchased 3 expensive items, their total purchase value would exceed Sondastan54's
# Out:
# 14.850000000000001

# %%
#Identify the the top 5 spenders in the game by total purchase value, then list (in a table)
#Using loc by record index
#long round-about method for finding this below
SN_shoppers_records = fantasy_data.loc[[79, 107, 131, 537, 596, 75, 304, 420, 754, 259, 337, 411, 708, 450, 464, 592, 623, 93, 218, 429, 767], :]
SN_shoppers_records
# Out:
#               SN  Age  Gender  Item ID                     Item Name  Price  \
# 79   Undirrala66   29    Male      144        Blood Infused Guardian   2.86
# 107  Undirrala66   29    Male      115    Spectral Diamond Doomblade   4.25
# 131  Undirrala66   29    Male       62                   Piece Maker   4.36
# 537  Undirrala66   29    Male       18    Torchlight, Bond of Storms   1.77
# 596  Undirrala66   29    Male      133              Faith's Scimitar   3.82
# 75   Sondastan54   31    Male       31                     Trickster   2.07
# 304  Sondastan54   31    Male      173           Stormfury Longsword   4.83
# 420  Sondastan54   31    Male      170                   Shadowsteel   1.98
# 754  Sondastan54   31    Male      104            Gladiator's Glaive   1.36
# 259     Saedue76   25    Male       13                      Serenity   1.49
# 337     Saedue76   25    Male      140                       Striker   3.82
# 411     Saedue76   25    Male        7  Thorn, Satchel of Dark Souls   4.51
# 708     Saedue76   25    Male       73                   Ritual Mace   3.74
# 450  Mindimnya67   39  Female      140                       Striker   3.82
# 464  Mindimnya67   39  Female      163          Thunderfury Scimitar   3.02
# 592  Mindimnya67   39  Female      145          Fiery Glass Crusader   4.45
# 623  Mindimnya67   39  Female      161                        Devine   1.45
# 93   Hailaphos89   20    Male       20                    Netherbane   1.48
# 218  Hailaphos89   20    Male       31                     Trickster   2.07
# 429  Hailaphos89   20    Male       82                       Nirvana   1.11
# 767  Hailaphos89   20    Male      122              Unending Tyranny   1.21
#
#     Age Range  SN_count
# 79      28-32       5.0
# 107     28-32       5.0
# 131     28-32       5.0
# 537     28-32       5.0
# 596     28-32       5.0
# 75      28-32       4.0
# 304     28-32       4.0
# 420     28-32       4.0
# 754     28-32       4.0
# 259     24-28       4.0
# 337     24-28       4.0
# 411     24-28       4.0
# 708     24-28       4.0
# 450     36-40       4.0
# 464     36-40       4.0
# 592     36-40       4.0
# 623     36-40       4.0
# 93      16-20       4.0
# 218     16-20       4.0
# 429     16-20       4.0
# 767     16-20       4.0

# %%
#list (in a table) SN, Purchase Count, Average Purchase Price, Total Purchase Value

# %%
SN_shoppers = fantasy_data.loc[fantasy_data["SN"] == "Hailaphos89"]
SN_shoppers.head()
# Out:
#               SN  Age Gender  Item ID         Item Name  Price Age Range  \
# 93   Hailaphos89   20   Male       20        Netherbane   1.48     16-20
# 218  Hailaphos89   20   Male       31         Trickster   2.07     16-20
# 429  Hailaphos89   20   Male       82           Nirvana   1.11     16-20
# 767  Hailaphos89   20   Male      122  Unending Tyranny   1.21     16-20
#
#      SN_count
# 93        4.0
# 218       4.0
# 429       4.0
# 767       4.0

# %%
SN_shoppers = fantasy_data.loc[fantasy_data["SN"] == "Mindimnya67"]
SN_shoppers.head()
# Out:
#               SN  Age  Gender  Item ID             Item Name  Price Age Range  \
# 450  Mindimnya67   39  Female      140               Striker   3.82     36-40
# 464  Mindimnya67   39  Female      163  Thunderfury Scimitar   3.02     36-40
# 592  Mindimnya67   39  Female      145  Fiery Glass Crusader   4.45     36-40
# 623  Mindimnya67   39  Female      161                Devine   1.45     36-40
#
#      SN_count
# 450       4.0
# 464       4.0
# 592       4.0
# 623       4.0

# %%
#Finding record index for top spenders. Wishing this were concatenating properly. 
SN_shoppers = fantasy_data.loc[fantasy_data["SN"] == "Undirrala66"]
SN_shoppers.head()
# Out:
#               SN  Age Gender  Item ID                   Item Name  Price  \
# 79   Undirrala66   29   Male      144      Blood Infused Guardian   2.86
# 107  Undirrala66   29   Male      115  Spectral Diamond Doomblade   4.25
# 131  Undirrala66   29   Male       62                 Piece Maker   4.36
# 537  Undirrala66   29   Male       18  Torchlight, Bond of Storms   1.77
# 596  Undirrala66   29   Male      133            Faith's Scimitar   3.82
#
#     Age Range  SN_count
# 79      28-32       5.0
# 107     28-32       5.0
# 131     28-32       5.0
# 537     28-32       5.0
# 596     28-32       5.0

# %%
SN_shoppers = fantasy_data.loc[fantasy_data["SN"] == "Saedue76"]
SN_shoppers.head()
# Out:
#            SN  Age Gender  Item ID                     Item Name  Price  \
# 259  Saedue76   25   Male       13                      Serenity   1.49
# 337  Saedue76   25   Male      140                       Striker   3.82
# 411  Saedue76   25   Male        7  Thorn, Satchel of Dark Souls   4.51
# 708  Saedue76   25   Male       73                   Ritual Mace   3.74
#
#     Age Range  SN_count
# 259     24-28       4.0
# 337     24-28       4.0
# 411     24-28       4.0
# 708     24-28       4.0

# %%
SN_shoppers = fantasy_data.loc[fantasy_data["SN"] == "Sondastan54"]
SN_shoppers.head()
# Out:
#               SN  Age Gender  Item ID            Item Name  Price
# 75   Sondastan54   31   Male       31            Trickster   2.07
# 304  Sondastan54   31   Male      173  Stormfury Longsword   4.83
# 420  Sondastan54   31   Male      170          Shadowsteel   1.98
# 754  Sondastan54   31   Male      104   Gladiator's Glaive   1.36

# %%
#SN_buyers = fantasy_data.loc[(fantasy_data["SN"].value_counts(>= 4))]
#print(SN_buyers)
# Out:
#   File "<ipython-input-50-e52e1ad14183>", line 1
#     SN_buyers = fantasy_data.loc[(fantasy_data["SN"].value_counts(>= 4))]
#                                                                    ^
# SyntaxError: invalid syntax

# %%
#Identify the the top 5 spenders in the game
#Most common SNs. These people purchase most often. Doesn't necessarily mean they spend the most. 
#Need to combine this with price data
#SN_unique = fantasy_data["SN"].value_counts().reset_index
#print(SN_unique)

# %%
#Identify the the top 5 spenders in the game by total purchase value, then list (in a table)
#SN, Purchase Count, Average Purchase Price, Total Purchase Value
#A bit unsure of how to approach this factoring in duplicated SNs. Will try grouping by unique identifier for SN
top_spenders = fantasy_data.sort_values("Price", ascending=False)
top_spenders.head()
# Out:
#                 SN  Age  Gender  Item ID Item Name  Price Age Range  SN_count  \
# 83   Frichaststa61   25  Female       32   Orenmir   4.95     24-28         1
# 50    Saistyphos30   32  Female       32   Orenmir   4.95     28-32         2
# 657     Tyarithn67   28    Male       32   Orenmir   4.95     24-28         1
# 388    Palurrian69   15    Male       32   Orenmir   4.95     12-16         1
# 227      Qiluard68   20    Male       32   Orenmir   4.95     16-20         1
#
#      User_total_purchase_value
# 83                        4.95
# 50                        4.95
# 657                       4.95
# 388                       4.95
# 227                       4.95

# %%
#Identify the 5 most popular items by purchase count, then list (in a table):
#Item ID, Item Name, Purchase Count, Item Price, Total Purchase Value
item_popularity = fantasy_data["Item Name"].value_counts()
print(item_popularity[:5])
#The top 5 are the most popular items- Final Critic:Retribution Axe
# Out:
# Final Critic                            14
# Betrayal, Whisper of Grieving Widows    11
# Arcane Gem                              11
# Stormcaller                             10
# Retribution Axe                          9
# Name: Item Name, dtype: int64

# %%
popular_items = gender_group = fantasy_data.groupby(["Item Name"])
popular_items.sort_values('popular_items', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-aacc1b9a4136> in <module>()
#       1 popular_items = gender_group = fantasy_data.groupby(["Item Name"])
# ----> 2 popular_items.sort_values('popular_items', ascending=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     546             return self[attr]
#     547         if hasattr(self.obj, attr):
# --> 548             return self._make_wrapper(attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _make_wrapper(self, name)
#     560                    "using the 'apply' method".format(kind, name,
#     561                                                      type(self).__name__))
# --> 562             raise AttributeError(msg)
#     563
#     564         # need to setup the selection
#
# AttributeError: Cannot access callable attribute 'sort_values' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
#sort_values(["Total"], ascending=False)

# %%
#Note: Item ID's and item names have different counts. 
#This means there are items which have the same name by multiple IDs. 
#We will sort by Name to find the most popular item 
item_popularity1 = fantasy_data["Item ID"].value_counts()
print(item_popularity1[:5])
# Out:
# 84     11
# 39     11
# 31      9
# 34      9
# 175     9
# Name: Item ID, dtype: int64

# %%
#Identify the 5 most profitable items by total purchase value, then list (in a table):
#Item ID, Item Name, Purchase Count, Item Price, Total Purchase Value
#Group by purchase value, sort descending. Filter by most popular.
